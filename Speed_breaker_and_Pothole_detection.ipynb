# %%
# %cd /content/drive/MyDrive/yolo_model/yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-172-gc3c1304 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.3/78.2 GB disk)

# %%
# Train YOLOv5s for 50 epochs image_resize = 350
# !python train.py --img 350 --batch 16 --epochs 50 --data /content/drive/MyDrive/yolo_model/yolov5/data/coco128.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/drive/MyDrive/yolo_model/yolov5/data/coco128.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=16, imgsz=350, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-172-gc3c1304 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
# !python detect.py --weights /content/drive/MyDrive/yolo_model/yolov5/runs/train/exp12/weights/best.pt --img 350 --conf 0.25 --source /content/drive/MyDrive/yolo_model/yolov5/data/dataset/speeeedddd.mp4
# Out:
# detect: weights=['/content/drive/MyDrive/yolo_model/yolov5/runs/train/exp12/weights/best.pt'], source=/content/drive/MyDrive/yolo_model/yolov5/data/dataset/speeeedddd.mp4, data=data/coco128.yaml, imgsz=[350, 350], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-172-gc3c1304 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# WARNING ⚠️ --img-size [350, 350] must be multiple of max stride 32, updating to [352, 352]
# video 1/1 (1/1493) /content/drive/MyDrive/yolo_model/yolov5/data/dataset/speeeedddd.mp4: 352x224 (no detections), 42.4ms
# ...
